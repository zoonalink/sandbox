# %% [markdown]
# # this does  not work

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

wayback_url = "https://web.archive.org/web/*/http://www.puppenhausmuseum.com/*"

response = requests.get(wayback_url)
soup = BeautifulSoup(response.text, 'html.parser')

image_urls = []

# Extracting image URLs using XPath
image_elements = soup.select('div#resultsUrl_wrapper table#resultsUrl tbody tr td.url a')
for element in image_elements:
    image_urls.append(element['href'])

# Set the directory to save the images
save_directory = 'downloaded_images'
os.makedirs(save_directory, exist_ok=True)

# Download and save images
for url in image_urls:
    image_url = urljoin(wayback_url, url)
    image_filename = os.path.join(save_directory, os.path.basename(url))
    
    response = requests.get(image_url)
    with open(image_filename, 'wb') as f:
        f.write(response.content)

print(f"{len(image_urls)} images downloaded and saved to {save_directory}.")
# Out:
# 0 images downloaded and saved to downloaded_images.

# %%
print(image_urls)
# Out:
# []

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

wayback_url = "https://web.archive.org/web/*/http://www.puppenhausmuseum.com/*"

response = requests.get(wayback_url)
soup = BeautifulSoup(response.text, 'html.parser')

image_urls = []

# Extracting image URLs directly from anchor elements
image_elements = soup.select('table#resultsUrl a')
for element in image_elements:
    image_urls.append(element['href'])

# Set the directory to save the images
save_directory = 'downloaded_images'
os.makedirs(save_directory, exist_ok=True)

# Download and save images
for url in image_urls:
    image_url = urljoin(wayback_url, url)
    image_filename = os.path.join(save_directory, os.path.basename(url))
    
    try:
        response = requests.get(image_url)
        response.raise_for_status()  # This will raise an HTTPError for bad responses.
        
        with open(image_filename, 'wb') as f:
            f.write(response.content)
            
        print(f"Image downloaded: {image_filename}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading image from {image_url}: {e}")

print(f"{len(image_urls)} images downloaded and saved to {save_directory}.")
# Out:
# 0 images downloaded and saved to downloaded_images.

# %%
import os
import requests
import re
from urllib.parse import urljoin

wayback_url = "https://web.archive.org/web/*/http://www.puppenhausmuseum.com/*"

response = requests.get(wayback_url)
html_content = response.text

# Use regular expression to extract image URLs
image_urls = re.findall(r'href="(http://www\.puppenhausmuseum\.com/bilder/puppenhaeuser/[^"]+\.jpg)"', html_content)

# Set the directory to save the images
save_directory = 'downloaded_images'
os.makedirs(save_directory, exist_ok=True)

# Download and save images
for url in image_urls:
    image_url = urljoin(wayback_url, url)
    image_filename = os.path.join(save_directory, os.path.basename(url))
    
    try:
        response = requests.get(image_url)
        response.raise_for_status()  # This will raise an HTTPError for bad responses.
        
        with open(image_filename, 'wb') as f:
            f.write(response.content)
            
        print(f"Image downloaded: {image_filename}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading image from {image_url}: {e}")

print(f"{len(image_urls)} images downloaded and saved to {save_directory}.")
# Out:
# 0 images downloaded and saved to downloaded_images.

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

wayback_url = "https://web.archive.org/web/*/http://www.puppenhausmuseum.com/*"

response = requests.get(wayback_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Print the entire HTML content to inspect its structure
print(soup.prettify())

image_urls = []

# Extracting image URLs directly from anchor elements
image_elements = soup.select('table#resultsUrl a')
for element in image_elements:
    image_urls.append(element['href'])

# Print the extracted image URLs
print("Image URLs:", image_urls)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Wayback Machine
#   </title>
#   <script>
#    /*
#     @licstart  The following is the entire license notice for the JavaScript code in this page.
#
#     Copyright (C) 2020 Internet Archive
#
#     The JavaScript code in this page is free software: you can
#     redistribute it and/or modify it under the terms of the GNU Affero
#     General Public License as published by the Free Software
#     Foundation, either version 3 of the License, or (at your option)
#     any later version.  The code is distributed WITHOUT ANY WARRANTY;
#     without even the implied warranty of MERCHANTABILITY or FITNESS
#     FOR A PARTICULAR PURPOSE.  See the GNU GPL for more details.
#
#     As additional permission under GNU AGPL version 3 section 7, you
#     may distribute non-source (e.g., minimized or compacted) forms of
#     that code without the copy of the GNU AGPL normally required by
# ...

# %%
import os
import requests
from waybackpy import WaybackMachine
from urllib.parse import urljoin
from bs4 import BeautifulSoup

url_to_archive = "http://www.puppenhausmuseum.com/"

# Save the URL to the Wayback Machine
wayback = WaybackMachine(url_to_archive)
wayback_url = wayback.save()

# Use a session to handle cookies and redirects
with requests.Session() as session:
    response = session.get(wayback_url)
    response.raise_for_status()

    # Extracting image URLs directly from anchor elements using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    image_elements = soup.select('table#resultsUrl a')
    image_urls = [element['href'] for element in image_elements]

    # Set the directory to save the images
    save_directory = 'downloaded_images'
    os.makedirs(save_directory, exist_ok=True)

    # Download and save images
    for url in image_urls:
        image_url = urljoin(wayback_url, url)
        image_filename = os.path.join(save_directory, os.path.basename(url))
        
        try:
            image_response = session.get(image_url)
            image_response.raise_for_status()
            
            with open(image_filename, 'wb') as f:
                f.write(image_response.content)
                
            print(f"Image downloaded: {image_filename}")
        except requests.exceptions.RequestException as e:
            print(f"Error downloading image from {image_url}: {e}")

print(f"{len(image_urls)} images downloaded and saved to {save_directory}.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\zoona\OneDrive - UWE Bristol\Modules\programming\useful\py-scrape-wayback.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/zoona/OneDrive%20-%20UWE%20Bristol/Modules/programming/useful/py-scrape-wayback.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> import os
#       <a href='vscode-notebook-cell:/c%3A/Users/zoona/OneDrive%20-%20UWE%20Bristol/Modules/programming/useful/py-scrape-wayback.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> import requests
# ----> <a href='vscode-notebook-cell:/c%3A/Users/zoona/OneDrive%20-%20UWE%20Bristol/Modules/programming/useful/py-scrape-wayback.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> from waybackpy import WaybackMachine
# ...

# %%
import os
import requests
from waybackpy import WaybackMachine
from urllib.parse import urljoin
from bs4 import BeautifulSoup

url_to_archive = "http://www.puppenhausmuseum.com/"

# Save the URL to the Wayback Machine
wayback = WaybackMachine(url_to_archive)
wayback_url = wayback.save()

# Use a session to handle cookies and redirects
with requests.Session() as session:
    response = session.get(wayback_url)
    response.raise_for_status()

    # Extracting image URLs directly from anchor elements using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    image_elements = soup.select('table#resultsUrl a')
    image_urls = [element['href'] for element in image_elements]

    # Set the directory to save the images
    save_directory = 'downloaded_images'
    os.makedirs(save_directory, exist_ok=True)

    # Download and save images
    for url in image_urls:
        image_url = urljoin(wayback_url, url)
        image_filename = os.path.join(save_directory, os.path.basename(url))
        
        try:
            image_response = session.get(image_url)
            image_response.raise_for_status()
            
            with open(image_filename, 'wb') as f:
                f.write(image_response.content)
                
            print(f"Image downloaded: {image_filename}")
        except requests.exceptions.RequestException as e:
            print(f"Error downloading image from {image_url}: {e}")

print(f"{len(image_urls)} images downloaded and saved to {save_directory}.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\zoona\OneDrive - UWE Bristol\Modules\programming\useful\py-scrape-wayback.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/zoona/OneDrive%20-%20UWE%20Bristol/Modules/programming/useful/py-scrape-wayback.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> import os
#       <a href='vscode-notebook-cell:/c%3A/Users/zoona/OneDrive%20-%20UWE%20Bristol/Modules/programming/useful/py-scrape-wayback.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> import requests
# ----> <a href='vscode-notebook-cell:/c%3A/Users/zoona/OneDrive%20-%20UWE%20Bristol/Modules/programming/useful/py-scrape-wayback.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> from waybackpy import WaybackMachine
# ...

# %%
import os
import requests
from waybackpy import WaybackMachineCDXServerAPI
from urllib.parse import urljoin
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

def download_images_from_wayback(url, user_agent="Your-user-agent", image_path="/bilder/puppenhaeuser/1002180914_kl.jpg"):
    # Create WaybackMachineCDXServerAPI object
    cdx = WaybackMachineCDXServerAPI(url=url, user_agent=user_agent, match_type="prefix")

    # Get snapshots from Wayback Machine
    snapshots = cdx.snapshots()

    # Set the directory to save the images
    save_directory = 'downloaded_images'
    os.makedirs(save_directory, exist_ok=True)

    # Retry mechanism
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)

    # Iterate through snapshots
    for snapshot in snapshots:
        print("Snapshot Date:", snapshot.timestamp)
        print("Archive URL:", snapshot.archive_url)

        # Access the original URL from the list
        original_url = snapshot.original[0]
        
        # Construct the correct image URL using the snapshot timestamp and image path
        image_url = f"https://web.archive.org/web/{snapshot.timestamp}/{urljoin(original_url, image_path)}"

        # Create the local filename for the image
        image_filename = os.path.join(save_directory, f"{snapshot.timestamp}_{os.path.basename(image_url)}")

        try:
            # Download and save the image with retries
            with requests.Session() as session:
                session.mount('https://', adapter)
                response = session.get(image_url)
                response.raise_for_status()

                # Save the image directly without checking content type
                with open(image_filename, 'wb') as f:
                    f.write(response.content)
                    
                print(f"Image downloaded: {image_filename}")

        except requests.exceptions.RequestException as e:
            print(f"Error downloading image from {image_url}: {e}")

    print(f"{len(snapshots)} images downloaded and saved to {save_directory}.")

# Example usage
wayback_url = "http://www.puppenhausmuseum.com/"
download_images_from_wayback(wayback_url)
# Out:
# Snapshot Date: 20020106120714
# Archive URL: https://web.archive.org/web/20020106120714/http://www.puppenhausmuseum.com:80/
# Image downloaded: downloaded_images\20020106120714_1002180914_kl.jpg
# Snapshot Date: 20020125135037
# Archive URL: https://web.archive.org/web/20020125135037/http://puppenhausmuseum.com:80/
# Image downloaded: downloaded_images\20020125135037_1002180914_kl.jpg
# Snapshot Date: 20020330174132
# Archive URL: https://web.archive.org/web/20020330174132/http://puppenhausmuseum.com:80/
# Image downloaded: downloaded_images\20020330174132_1002180914_kl.jpg
# Snapshot Date: 20020525134222
# Archive URL: https://web.archive.org/web/20020525134222/http://puppenhausmuseum.com:80/
# Image downloaded: downloaded_images\20020525134222_1002180914_kl.jpg
# Snapshot Date: 20020603082215
# Archive URL: https://web.archive.org/web/20020603082215/http://puppenhausmuseum.com:80/
# Image downloaded: downloaded_images\20020603082215_1002180914_kl.jpg
# ...
